# %% [markdown]
# ## 알바 주급 데이터 문제

# %% [markdown]
# ### 0. 데이터를 Load 하세요

# %%
import pandas as pd
# Out:
#         이름     시급  일간 근무 시간  주간 근무 일수  연장 근무  수습 시간 여부   세전 주급  주휴 수당  \
# 0      이준미  10440         6         3      5      True  170256  34051
# 1      김재연  11600         5         5      5     False  262740  52548
# 2      김찬하   9600         7         2      4     False  129964      0
# 3      이지하  10350        12         5      3      True  562625  75017
# 4      소승하   9090         7         3      4      True  172947  34589
# ...    ...    ...       ...       ...    ...       ...     ...    ...
# 19995  안재보   8640         3         5      0      True  125325  25065
# 19996  윤미주  10400        12         3      0     False  339207  67841
# 19997  조창석   9540        10         6      3      True  518592  69146
# 19998  이의영  10800         9         5      0     False  440315  78278
# 19999  이가저  10620        11         5      0      True  529195  76974
#
#        연장 근무 수당   세후 급여
# 0         70940  275247
# 1         78822  394110
# 2         55699  185663
# 3         42197  679839
# ...

# %% [markdown]
# ### 1. 데이터에 결측치가 있는지 확인하세요
# - 실제로는 결측치 없음

# %%
# Out:
# 이름          0
# 시급          0
# 일간 근무 시간    0
# 주간 근무 일수    0
# 연장 근무       0
# 수습 시간 여부    0
# 세전 주급       0
# 주휴 수당       0
# 연장 근무 수당    0
# 세후 급여       0
# dtype: int64

# %% [markdown]
# ### 2. 세후 주급이 330,000원이 넘는 데이터를 조회하세요

# %%
# Out:
#         이름     시급  일간 근무 시간  주간 근무 일수  연장 근무  수습 시간 여부   세전 주급  주휴 수당  \
# 1      김재연  11600         5         5      5     False  262740  52548
# 3      이지하  10350        12         5      3      True  562625  75017
# 5      김시모   8820        10         6      0      True  479454  63927
# 11     이상하  11100         9         3      5     False  271527  54306
# 15     강재하   9180        11         4      0      True  365952  66537
# ...    ...    ...       ...       ...    ...       ...     ...    ...
# 19994  장견하  11900        12         3      0     False  388131  77626
# 19996  윤미주  10400        12         3      0     False  339207  67841
# 19997  조창석   9540        10         6      3      True  518592  69146
# 19998  이의영  10800         9         5      0     False  440315  78278
# 19999  이가저  10620        11         5      0      True  529195  76974
#
#        연장 근무 수당   세후 급여
# 1         78822  394110
# 3         42197  679839
# 5             0  543381
# 11        75424  401257
# ...

# %% [markdown]
# ### 3. 일간 근무시간 히스토그램
# - 일간 근무시간 데이터를 히스토그램으로 나타내세요.
# - 근무시간은 3~12 사이의 정수 입니다.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 4. 근로기준법 명시 근로 시간을 초과하여 근로한 데이터를 조회하세요
# - 근로기준법상 일 8시간, 주 40시간을 초과하여 근무한 경우 근로기준을 초과한 연장근무에 해당합니다.
# - 연장 근무로 명시된 근로 시간은 해당 시간에 포함되지 않습니다.

# %%
# Out:
#        이름     시급  일간 근무 시간  주간 근무 일수  연장 근무  수습 시간 여부   세전 주급  주휴 수당  \
# 0     이지하  10350        12         5      3      True  562625  75017
# 1     김시모   8820        10         6      0      True  479454  63927
# 2     곽지하   9270        12         2      0      True  201566  40313
# 3     우하우   9600         9         3      0     False  234834  46967
# 4     이상하  11100         9         3      5     False  271527  54306
# ...   ...    ...       ...       ...    ...       ...     ...    ...
# 7982  장견하  11900        12         3      0     False  388131  77626
# 7983  윤미주  10400        12         3      0     False  339207  67841
# 7984  조창석   9540        10         6      3      True  518592  69146
# 7985  이의영  10800         9         5      0     False  440315  78278
# 7986  이가저  10620        11         5      0      True  529195  76974
#
#       연장 근무 수당   세후 급여
# 0        42197  679839
# 1            0  543381
# 2            0  241879
# 3            0  281801
# ...

# %% [markdown]
# ### 5. 수습 여부에 따른 세후 급여 비교 히스토그램을 그리세요
# - 수습 여부를 True / False 로 나눔
# - bins 개수는 10로 함
# - bins의 크기는 0.7로 함
